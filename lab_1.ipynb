# %% [markdown]
# # Python Review
# Functions
# Get Requests
# Pandas

# %%
import os
import requests
import pandas as pd

# %%
path = os.path.join(os.getcwd(), 'Documents', 'GitHub', 'Sarah-Discussion-Notebooks')
path
# Out:
# '/Users/Sarah/Documents/GitHub/Sarah-Discussion-Notebooks'

# %%
os.chdir(path) #set working directory -may not be needed, depending on how you are running your code

# %%
os.getcwd()
# Out:
# '/Users/Sarah/Documents/GitHub/Sarah-Discussion-Notebooks'

# %% [markdown]
# Let's look at Chicago population Data
# Chicago Health Atlaas:
# https://www.chicagohealthatlas.org/indicators/total-population

# %%
url = 'https://citytech-health-atlas-data-prod.s3.amazonaws.com/uploads/uploader/path/557/Total_population.xlsx'
filename = 'Chi_pop.xls'

# %%
response = requests.get(url)
output = response.content
with open(filename, 'wb') as ofile:
    ofile.write(output)

# %%
df = pd.read_excel(os.path.join(path, filename))
df
# Out:
#        Category SubCategory         Indicator       Year       Geography  \
# 0    Demography   Age Group  Total population       2017            City
# 1    Demography   Age Group  Total population       2017            City
# 2    Demography   Age Group  Total population       2017            City
# 3    Demography   Age Group  Total population       2017            City
# 4    Demography   Age Group  Total population       2017            City
# ..          ...         ...               ...        ...             ...
# 378  Demography   Age Group  Total population  2006-2010  Community Area
# 379  Demography   Age Group  Total population  2006-2010  Community Area
# 380  Demography   Age Group  Total population  2006-2010  Community Area
# 381  Demography   Age Group  Total population  2006-2010  Community Area
# 382  Demography   Age Group  Total population  2006-2010  Community Area
#
#                  Geo_Group  Geo_ID      Demography            Demo_Group  \
# 0                  Chicago     606  Race-ethnicity  All race-ethnicities
# 1                  Chicago     606             Age                   0-4
# 2                  Chicago     606             Age                   5-9
# 3                  Chicago     606             Age                 10-14
# 4                  Chicago     606             Age                15-19
# ..                     ...     ...             ...                   ...
# 378  73-Washington Heights     606             NaN                   NaN
# 379     74-Mount Greenwood     606             NaN                   NaN
# 380         75-Morgan Park     606             NaN                   NaN
# 381              76-O'Hare     606             NaN                   NaN
# 382           77-Edgewater     606             NaN                   NaN
#
#       Number  ...  Upper_95CI_Age_Adj_Rate  Percent  Lower_95CI_Percent  \
# 0    2716462  ...                      NaN      NaN                 NaN
# 1     172017  ...                      NaN      6.3                 NaN
# 2     150373  ...                      NaN      5.5                 NaN
# 3     155283  ...                      NaN      5.7                 NaN
# 4     153896  ...                      NaN      5.7                 NaN
# ..       ...  ...                      ...      ...                 ...
# 378    27643  ...                      NaN      NaN                 NaN
# 379    18497  ...                      NaN      NaN                 NaN
# 380    27313  ...                      NaN      NaN                 NaN
# 381    20669  ...                      NaN      NaN                 NaN
# 382    56605  ...                      NaN      NaN                 NaN
#
#      Upper_95CI_Percent  Weight_Number  Weight_Percent  \
# 0                   NaN            NaN             NaN
# 1                   NaN            NaN             NaN
# 2                   NaN            NaN             NaN
# 3                   NaN            NaN             NaN
# 4                   NaN            NaN             NaN
# ..                  ...            ...             ...
# 378                 NaN            NaN             NaN
# 379                 NaN            NaN             NaN
# 380                 NaN            NaN             NaN
# 381                 NaN            NaN             NaN
# 382                 NaN            NaN             NaN
#
#      Lower_95CI_Weight_Percent  Upper_95CI_Weight_Percent    Map_Key  Flag
# 0                          NaN                        NaN        NaN     G
# 1                          NaN                        NaN        NaN     G
# 2                          NaN                        NaN        NaN     G
# 3                          NaN                        NaN        NaN     G
# 4                          NaN                        NaN        NaN     G
# ..                         ...                        ...        ...   ...
# 378                        NaN                        NaN  quintiles     G
# 379                        NaN                        NaN  quintiles     G
# 380                        NaN                        NaN  quintiles     G
# 381                        NaN                        NaN  quintiles     G
# 382                        NaN                        NaN  quintiles     G
#
# [383 rows x 27 columns]

# %%
df.shape
# Out:
# (383, 27)

# %%
df['N']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-78a33f69c558> in <module>
# ----> 1 df[1]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
